# %% [markdown]
# # IMPORTS

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
#import math
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# import seaborn as sns

# import matplotlib.pyplot as plt
# from IPython.core.display import HTML

# from IPython.display import Image

# %% [markdown]
# ## Helper Functions

# %%
# def jupyter_settings():
#     %matplotlib inline
#     %pylab inline
    
#     plt.style.use( 'bmh' )
#     plt.rcParams['figure.figsize'] = [25, 12]
#     plt.rcParams['font.size'] = 24
    
#     display( HTML( '<style>.container { width:100% !important; }</style>') )
#     pd.options.display.max_columns = None
#     pd.options.display.max_rows = None
#     pd.set_option( 'display.expand_frame_repr', False )
    
#     sns.set()

# %%
# jupyter_settings()

# %% [markdown]
# ## Loading Data

# %%
dfRaw = pd.read_csv('../01-Data/Results/01-CRISPData/train.csv', low_memory=False, parse_dates=['Date'])

# %% [markdown]
# # FEATURE ENGINEERING

# %%
dfRaw1 = dfRaw.copy()

# %%
#year
dfRaw1['Year'] = dfRaw1['Date'].dt.year

#month
dfRaw1['Month'] = dfRaw1['Date'].dt.month

#day
dfRaw1['Day'] = dfRaw1['Date'].dt.day

#week of year
dfRaw1['WeekOfYear'] = dfRaw1['Date'].dt.weekofyear

#year week
dfRaw1['YearWeek'] = dfRaw1['Date'].dt.strftime('%Y-%W')

# %%
dfRaw1.head().T
# Out:
#                                              0                    1  \
# Store                                        1                    2
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     5263                 6064
# Customers                                  555                  625
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                                 0                    0
# SchoolHoliday                                1                    1
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                  570
# CompetitionOpenSinceMonth                    9                   11
# CompetitionOpenSinceYear                  2008                 2007
# Promo2                                       0                    1
# Promo2SinceWeek                             31                   13
# Promo2SinceYear                             31                 2010
# PromoInterval                                0      Jan,Apr,Jul,Oct
# MonthMap                                   Jul                  Jul
# IsPromo                                      0                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Day                                         31                   31
# WeekOfYear                                  31                   31
# YearWeek                               2015-30              2015-30
#
#                                              2                    3  \
# Store                                        3                    4
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     8314                13995
# Customers                                  821                 1498
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                                 0                    0
# SchoolHoliday                                1                    1
# StoreType                                    a                    c
# Assortment                                   a                    c
# CompetitionDistance                      14130                  620
# CompetitionOpenSinceMonth                   12                    9
# CompetitionOpenSinceYear                  2006                 2009
# Promo2                                       1                    0
# Promo2SinceWeek                             14                   31
# Promo2SinceYear                           2011                   31
# PromoInterval                  Jan,Apr,Jul,Oct                    0
# MonthMap                                   Jul                  Jul
# IsPromo                                      1                    0
# Year                                      2015                 2015
# Month                                        7                    7
# Day                                         31                   31
# WeekOfYear                                  31                   31
# YearWeek                               2015-30              2015-30
#
#                                              4
# Store                                        5
# DayOfWeek                                    5
# Date                       2015-07-31 00:00:00
# Sales                                     4822
# Customers                                  559
# Open                                         1
# Promo                                        1
# StateHoliday                                 0
# SchoolHoliday                                1
# StoreType                                    a
# Assortment                                   a
# CompetitionDistance                      29910
# CompetitionOpenSinceMonth                    4
# CompetitionOpenSinceYear                  2015
# Promo2                                       0
# Promo2SinceWeek                             31
# Promo2SinceYear                             31
# PromoInterval                                0
# MonthMap                                   Jul
# IsPromo                                      0
# Year                                      2015
# Month                                        7
# Day                                         31
# WeekOfYear                                  31
# YearWeek                               2015-30
